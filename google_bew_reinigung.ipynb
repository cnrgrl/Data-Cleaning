# %%
import pandas as pd

# %%
df = pd.read_csv('csv/merged_all_google.csv')

# %%
# Print data types of DataFrame
df.dtypes
# Out:
# Bewertung_ID             int64
# Klinik_ID                int64
# Name_Klinik             object
# Bewertung_Datum         object
# Sternebewertung         object
# Textuelle_Bewertung     object
# Likes                  float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2034 entries, 0 to 2033
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Bewertung_ID         2034 non-null   int64
#  1   Klinik_ID            2034 non-null   int64
#  2   Name_Klinik          2034 non-null   object
#  3   Bewertung_Datum      2034 non-null   object
#  4   Sternebewertung      2034 non-null   object
#  5   Textuelle_Bewertung  1510 non-null   object
#  6   Likes                1015 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 111.4+ KB

# %%
df.describe()
# Out:
#        Bewertung_ID    Klinik_ID        Likes
# count   2034.000000  2034.000000  1015.000000
# mean      78.908555    10.813668     3.384236
# std       67.377460     6.257092     3.169776
# min        1.000000     1.000000     1.000000
# 25%       29.000000     6.000000     1.000000
# 50%       60.000000    10.000000     2.000000
# 75%      107.000000    16.000000     4.000000
# max      303.000000    24.000000    23.000000

# %%
df.isna().sum()
# Out:
# Bewertung_ID              0
# Klinik_ID                 0
# Name_Klinik               0
# Bewertung_Datum           0
# Sternebewertung           0
# Textuelle_Bewertung     524
# Likes                  1019
# dtype: int64

# %%
df.head(20)
# Out:
#     Bewertung_ID  Klinik_ID                         Name_Klinik  \
# 0              1         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 1              2         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 2              3         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 3              4         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 4              5         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 5              6         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 6              7         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 7              8         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 8              9         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 9             10         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 10            11         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 11            12         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 12            13         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# 13            14         16  AGAPLESION EV. KLINIKUM SCHAUMBURG
# ...
